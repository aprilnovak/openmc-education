# %% [markdown]
# # Best Practices with OpenMC
#
# In this tutorial, we'll learn about how to use OpenMC efficiently and correctly.

# %% [markdown]
# ## Lattices vs. Flat Geometries
#
# To obtain good tracking performance (particles/s that OpenMC can simulate), you should think carefully about how the geometry is constructed. In general, universes and lattices will perform better than "flat" universes, because when a particle moves into an adjacent cell, a lattice immediately has a "rule" for finding the identity of the adjacent cell.

# %%
import openmc

model = openmc.Model()
model.settings.particles = 10000
model.settings.inactive = 50
model.settings.batches = 100

# %%
mat1 = openmc.Material()
mat1.add_element('U', 1.0)
mat1.set_density('g/cm3', 11.0)

mat2 = openmc.Material()
mat2.add_nuclide('Pu239', 1.0)
mat2.set_density('g/cm3', 11.0)

zcyl = openmc.ZCylinder(r=0.4)
cyl = openmc.Cell(fill=mat1, region=-zcyl)
ocyl = openmc.Cell(fill=mat2, region=+zcyl)

univ = openmc.Universe(cells=[ocyl, cyl])
univ.plot(width=(2, 2))
# Out:
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %% [markdown]
# Let's build a geometry containing $N^2$ squares all filled with this material, in one of two different ways:
#
# - a NxN rectilinear lattice (a "nested" geometry)
# - building the x-y planes and filling our universe into each slot (a "flat" geometry)

# %%
N = 50
pitch = 1

# %% [markdown]
# #### Option 1: Lattice

# %%
lattice = openmc.RectLattice()
lattice.lower_left = (-N*pitch/2, -N*pitch/2)
lattice.pitch = (pitch, pitch)
lattice.universes = [[univ] * N] * N
print(lattice.universes.shape)
# Out:
# (50, 50)

# %%
bound = openmc.model.RectangularPrism(N*pitch, N*pitch, boundary_type='reflective')
root_universe1 = openmc.Universe()
root_universe1.add_cell(openmc.Cell(region=-bound, fill=lattice))
root_universe1.plot(width=(N*pitch,N*pitch), color_by='material', pixels=(500,500))
# Out:
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %%
model.geometry = openmc.Geometry(root_universe1)

# %%
statepoint = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2026 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.4-dev144
#      Commit Hash | 9ff50499e133e1b977391dd1ff284b9eccb08958
#        Date/Time | 2026-06-10 16:34:58
#    MPI Processes | 1
#   OpenMP Threads | 10
#
#  Reading model XML file 'model.xml' ...
#  Reading chain file:
#  /Users/anovak/projects/cross_sections/endfb-vii.1-hdf5/depletion_chain.xml...
#  Reading cross sections XML file...
#  Reading U234 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U234.h5
#  Reading U235 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U235.h5
#  Reading U238 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U238.h5
#  Reading Pu239 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Pu239.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Pu239
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    2.67828
#         2/1    2.70965
#         3/1    2.70680
#         4/1    2.65516
#         5/1    2.67169
#         6/1    2.68555
#         7/1    2.71599
#         8/1    2.71449
#         9/1    2.66353
#        10/1    2.67663
#        11/1    2.69672
#        12/1    2.68886
#        13/1    2.67400
#        14/1    2.66892
#        15/1    2.63010
#        16/1    2.71647
#        17/1    2.63229
#        18/1    2.66469
#        19/1    2.63266
#        20/1    2.64183
#        21/1    2.65488
#        22/1    2.68301
#        23/1    2.68677
#        24/1    2.66570
#        25/1    2.64985
#        26/1    2.74856
#        27/1    2.67322
#        28/1    2.70704
#        29/1    2.72416
#        30/1    2.66535
#        31/1    2.64188
#        32/1    2.69549
#        33/1    2.71223
#        34/1    2.65927
#        35/1    2.71157
#        36/1    2.66138
#        37/1    2.69816
#        38/1    2.68760
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.0275e-01 seconds
#    Reading cross sections          = 3.8956e-01 seconds
#  Total time in simulation          = 2.0108e+00 seconds
#    Time in transport only          = 1.9806e+00 seconds
#    Time in inactive batches        = 1.0029e+00 seconds
#    Time in active batches          = 1.0080e+00 seconds
#    Time synchronizing fission bank = 2.0147e-02 seconds
#      Sampling source sites         = 1.8659e-02 seconds
#      SEND/RECV source sites        = 1.4216e-03 seconds
#    Time accumulating tallies       = 3.2900e-06 seconds
#    Time writing statepoints        = 3.0708e-03 seconds
#  Total time for finalization       = 5.0000e-07 seconds
#  Total time elapsed                = 2.5155e+00 seconds
#  Calculation Rate (inactive)       = 498578 particles/second
#  Calculation Rate (active)         = 496055 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 2.68573 +/- 0.00330
#  k-effective (Track-length)  = 2.68609 +/- 0.00363
#  k-effective (Absorption)    = 2.67903 +/- 0.00097
#  Combined k-effective        = 2.67961 +/- 0.00098
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# ### Option 2: "Flat" Geometry
#
# Let's build the same geometry, but now without using a lattice.

# %%
import numpy as np
xplanes = [openmc.XPlane(x0=x) for x in np.linspace(-N*pitch/2, N*pitch/2, N+1)]
yplanes = [openmc.YPlane(y0=y) for y in np.linspace(-N*pitch/2, N*pitch/2, N+1)]

xplanes[0].boundary_type = 'reflective'
xplanes[-1].boundary_type = 'reflective'
yplanes[0].boundary_type = 'reflective'
yplanes[-1].boundary_type = 'reflective'

# %%
cells = []
for x in range(len(xplanes) - 1):
    for y in range(len(yplanes) - 1):
        left = xplanes[x]
        right = xplanes[x + 1]
        bottom = yplanes[y]
        top = yplanes[y + 1]
        
        x0 = (xplanes[x].x0 + xplanes[x + 1].x0) / 2
        y0 = (yplanes[y].y0 + yplanes[y + 1].y0) / 2
        
        cylinder = openmc.ZCylinder(r=0.4, x0=x0, y0=y0)
        cells.append(openmc.Cell(region=-cylinder, fill=mat1))
        cells.append(openmc.Cell(region=+cylinder & +left & -right & +bottom & -top, fill=mat2))

# %%
root_universe2 = openmc.Universe(cells=cells)
root_universe2.plot(width=(N*pitch,N*pitch), pixels=(500,500))
root_universe2.plot(width=(N*pitch,N*pitch), color_by='material', pixels=(500,500))
# Out:
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %% [markdown]
# We have created an identical geometry! Of course, this took more human effort to establish instead of using a lattice. But that's not the only important difference -- this "flat" version of the geometry will also be *slower*.

# %%
model.geometry = openmc.Geometry(root_universe2)
statepoint = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2026 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.4-dev144
#      Commit Hash | 9ff50499e133e1b977391dd1ff284b9eccb08958
#        Date/Time | 2026-06-10 16:35:09
#    MPI Processes | 1
#   OpenMP Threads | 10
#
#  Reading model XML file 'model.xml' ...
#  Reading chain file:
#  /Users/anovak/projects/cross_sections/endfb-vii.1-hdf5/depletion_chain.xml...
#  Reading cross sections XML file...
#  Reading U234 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U234.h5
#  Reading U235 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U235.h5
#  Reading U238 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U238.h5
#  Reading Pu239 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Pu239.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Pu239
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    2.67828
#         2/1    2.70965
#         3/1    2.70680
#         4/1    2.65516
#         5/1    2.67169
#         6/1    2.68555
#         7/1    2.71599
#         8/1    2.71449
#         9/1    2.66353
#        10/1    2.67663
#        11/1    2.69672
#        12/1    2.68886
#        13/1    2.67400
#        14/1    2.66892
#        15/1    2.63010
#        16/1    2.71647
#        17/1    2.63229
#        18/1    2.66469
#        19/1    2.63266
#        20/1    2.64183
#        21/1    2.65488
#        22/1    2.68301
#        23/1    2.68677
#        24/1    2.66570
#        25/1    2.64985
#        26/1    2.74856
#        27/1    2.67322
#        28/1    2.70704
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4072e+00 seconds
#    Reading cross sections          = 3.3274e-01 seconds
#  Total time in simulation          = 5.1358e+00 seconds
#    Time in transport only          = 5.1048e+00 seconds
#    Time in inactive batches        = 2.6296e+00 seconds
#    Time in active batches          = 2.5062e+00 seconds
#    Time synchronizing fission bank = 2.1271e-02 seconds
#      Sampling source sites         = 1.9738e-02 seconds
#      SEND/RECV source sites        = 1.3775e-03 seconds
#    Time accumulating tallies       = 6.7080e-06 seconds
#    Time writing statepoints        = 2.0252e-03 seconds
#  Total time for finalization       = 5.8400e-07 seconds
#  Total time elapsed                = 6.5810e+00 seconds
#  Calculation Rate (inactive)       = 190142 particles/second
#  Calculation Rate (active)         = 199504 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 2.68573 +/- 0.00330
#  k-effective (Track-length)  = 2.68609 +/- 0.00363
#  k-effective (Absorption)    = 2.67903 +/- 0.00097
#  Combined k-effective        = 2.67961 +/- 0.00098
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# This model ran about 3x slower than a (physically identical) version using a lattice. If you can build your geometry to take advantage of lattices, it is a good idea to do so.

# %% [markdown]
# # Using OpenMC Correctly
#
# Monte Carlo "run strategy" generally consists of three choices:
#
# - Number of batches (`model.settings.batches`)
# - Number of inactive batches (`model.settings.inactive`)
# - Number of particles per batch (`model.settings.particles`)
# - Number of generations per batch (`model.settings.generations_per_batch`)
#
# In addition, for k-eigenvalue calculations you elect the initial source distribution. We will individually explore each of these choices. First, let's describe what these terms mean exactly.
#
# ### What is a generation?
#
# During each generation in OpenMC:
#
# - `model.settings.particles` sites are sampled from a bank of fission sites
# - Those particles are transported from birth until "death" (leakage or absorption)
# - Any new neutrons which are produced during their lifetime (e.g., from fission) have their birth position, energy, and angle stored in a new fission bank.
#
# Therefore, each time a new generation begins, the sites used to sample the neutron positions are those which were "banked" from the previous generation.
#
# ### What is a batch?
#
# A batch is a group of generations as one statistical realization. By default, `model.settings.generations_per_batch` is unity, in which case a batch is synonymous with a generation.
#
# ### What is an inactive batch?
#
# An inactive batch involves the transport of neutrons, but not accumulation of any tallies.
#
# ### What is an active batch?
#
# An active batch involves the transport of neutrons AND accumulation of tallies.

# %% [markdown]
# ## Inactive batches and initial source
#
# For the very first generation run in OpenMC (the first generation of the first batch), we don't yet have a bank of sites to sample neutrons from. Therefore, the user has to provide a "guess" for the starting source, using `model.settings.source`. By default, this source distribution is taken to be a point source at the origin. In all k-eigenvalue cases, you don't know the source distribution, so whatever choice you make is a GUESS. However, we don't want to start accumulating tally statistics until our guessed source distribution undergoes enough generations so that it has statistically converged. Otherwise, even if you run a high number of particles/batch, your answers will be WRONG (but PRECISE!).
#
# The factors you choose are:
#
# - The starting source distribution. Ideally, you'd like this to be as close as possible to the true source distribution.
# - The number of inactive batches. The higher this number is, the more likely you are to have evolved from your (WRONG) initial source to the true initial source.

# %% [markdown]
# To explore these effects, let's choose an initial source distribution which is clearly not the correct, converged source distribution. When choosing a source distribution, we will use the [`openmc.stats` module](https://docs.openmc.org/en/stable/pythonapi/stats.html), which contains probability distributions to sample from which we can use for energy, angle, and space.

# %%
model = openmc.examples.pwr_pin_cell()
model.geometry.root_universe.plot()
# Out:
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %%
model.geometry.bounding_box
# Out:
# BoundingBox(lower_left=(-0.63, -0.63, -inf), upper_right=(0.63, 0.63, inf))

# %%
bottom = openmc.ZPlane(z0=-150, boundary_type='vacuum')
top = openmc.ZPlane(z0=150, boundary_type='vacuum')
box = openmc.model.RectangularPrism(0.63*2, 0.63*2, boundary_type='reflective')
outer_cell = openmc.Cell(region=-box & +bottom & -top, fill=model.geometry.root_universe)
root_universe = openmc.Universe(cells=[outer_cell])
model.geometry.root_universe = root_universe

# %% [markdown]
# Let's make a source distribution which only exists over the lower half of the pincell -- as if the entire upper half had no fission at all. Clearly this is a very bad guess!

# %%
x = openmc.stats.Uniform(-0.63, 0.63)
y = openmc.stats.Uniform(-0.63, 0.63)
z = openmc.stats.Uniform(-150, 0)
space = openmc.stats.CartesianIndependent(x=x, y=y, z=z)
model.settings.source = openmc.IndependentSource(space=space)

# %% [markdown]
# In order to "see" the effect of having a wrong initial source distribution, we will need to add a tally to visualize a quantity affected by a wrong source distribution. Let's take a look at the heating distribution.

# %%
heat = openmc.Tally()
heat.scores = ['kappa-fission']

mesh = openmc.RegularMesh()
mesh.lower_left = (-0.63, -0.63, -150)
mesh.upper_right = (0.63, 0.63, 150)
mesh.dimension = (1, 1, 50)

heat.filters = [openmc.MeshFilter(mesh=mesh)]

model.tallies = [heat]

# %% [markdown]
# Now, we will run this model with different choices for numbers of inactive batches. As long as we run enough inactive batches, we can evolve away from this very wrong source distribution to the true, cosine distribution we expect.

# %%
import matplotlib.pyplot as plt

# %%
model.settings.particles = 1000 

fig, ax = plt.subplots()

for i in [10, 20, 100, 500]:
    model.settings.batches = i + 100
    statepoint = model.run(output=False, apply_tally_results=True)    
    ax.plot(heat.get_values().flatten(), label='{} inactive'.format(i))
    
plt.legend()
plt.grid()
plt.xlabel('Height')
plt.ylabel('Kappa-Fission (unnormalized)')
# Out:
# Text(0, 0.5, 'Kappa-Fission (unnormalized)')

# %% [markdown]
# We can see that we need more and more inactive batches if we want our fission source distribution to approach the true distribution. If you increase the number of particles, the statistical noisiness will decrease, but it won't help us to get closer to the true distribution for the sampled source. As a rule of thumb on selecting the inactive batches:
#
# - Small problems (critical assemblies, pin cell): O(10) batches
# - Medium problems (assemblies, fast reactor): O(10)–O(100) batches
# - Large problems (PWR core, spent fuel pool): O(100)–O(1000) batches?
#
# The dominance ratio, or the ratio of the second-largest eigenvalue to the largest eigenvalue, dictates the convergence rate of power iteration (each generation in a Monte Carlo simulation is a power iteration).
#
# If we change our initial guess for the source distribution to something more realistic, we'll be able to use fewer inactive batches before we start collecting tally statistics.

# %%
z = openmc.stats.Uniform(-150, 150)
space = openmc.stats.CartesianIndependent(x=x, y=y, z=z)
model.settings.source = openmc.IndependentSource(space=space)

# %%
model.settings.particles = 1000

fig, ax = plt.subplots()

for i in [10, 20, 100, 500]:
    model.settings.batches = i + 100
    statepoint = model.run(output=False, apply_tally_results=True)
    ax.plot(heat.get_values().flatten(), label='{} inactive'.format(i))
    
plt.legend()
plt.grid()
plt.xlabel('Height')
plt.ylabel('Kappa-Fission (unnormalized)')
# Out:
# Text(0, 0.5, 'Kappa-Fission (unnormalized)')

# %% [markdown]
# ## Shannon Entropy
#
# Shannon entropy is a concept from information theory that characterizes how much "information" a bit stream stores. In the context of eigenvalue calculations, it has been shown that when a source distibution is discretized over a mesh, the entropy of the source probability converges as the distribution itself reaches stationarity. Shannon entropy is defined as:
#
# $$ H = - \sum_i p_i \log_2 p_i $$
#
# where $p_i$ is the fraction of source particles in mesh cell $i$. In essence, we superimpose a mesh onto our geometry, and assess stationarity of the fission source by looking for stationarity in the Shannon entropy.
#
# We'll need to create a `RegularMesh` object that will be used to count source particles over and calculate Shannon entropy. We can use the same mesh used for talling the fission source earlier (though this is not a requirement).

# %%
model.settings.entropy_mesh = mesh

# %%
statepoint = model.run(apply_tally_results = True)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2026 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.4-dev144
#      Commit Hash | 9ff50499e133e1b977391dd1ff284b9eccb08958
#        Date/Time | 2026-06-10 16:35:38
#    MPI Processes | 1
#   OpenMP Threads | 10
#
#  Reading model XML file 'model.xml' ...
#  Reading chain file:
#  /Users/anovak/projects/cross_sections/endfb-vii.1-hdf5/depletion_chain.xml...
#  Reading cross sections XML file...
#  Reading U234 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U234.h5
#  Reading U235 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U235.h5
#  Reading U238 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U238.h5
#  Reading O16 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/O16.h5
#  Reading Zr90 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr90.h5
#  Reading Zr91 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr91.h5
#  Reading Zr92 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr92.h5
#  Reading Zr94 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr94.h5
#  Reading Zr96 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr96.h5
#  WARNING: Negative value(s) found on probability table for nuclide Zr96 at 294K
#  Reading H1 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/H1.h5
#  Reading B10 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/B10.h5
#  Reading B11 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/B11.h5
#  Reading c_H_in_H2O from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/thermal/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Zr90
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k       Entropy         Average k
#   =========   ========   ========   ====================
#         1/1    1.13730    5.58624
#         2/1    1.23235    5.55899
#         3/1    1.13856    5.54628
#         4/1    1.16404    5.50055
#         5/1    1.12653    5.49812
#         6/1    1.05134    5.52788
#         7/1    1.21560    5.52718    1.13347 +/- 0.08213
#         8/1    1.15514    5.48659    1.14069 +/- 0.04797
#         9/1    1.12650    5.46268    1.13714 +/- 0.03410
#        10/1    1.14170    5.46691    1.13805 +/- 0.02643
#        11/1    1.06846    5.44534    1.12646 +/- 0.02450
#        12/1    1.15057    5.44546    1.12990 +/- 0.02099
#        13/1    1.15694    5.39860    1.13328 +/- 0.01849
#        14/1    1.14390    5.41506    1.13446 +/- 0.01635
#        15/1    1.20211    5.41494    1.14123 +/- 0.01611
#        16/1    1.13731    5.41123    1.14087 +/- 0.01458
#        17/1    1.18268    5.38688    1.14435 +/- 0.01376
#        18/1    1.20714    5.43348    1.14918 +/- 0.01354
#        19/1    1.13077    5.44126    1.14787 +/- 0.01261
#        20/1    1.09250    5.43788    1.14418 +/- 0.01230
#        21/1    1.11037    5.44658    1.14206 +/- 0.01170
#        22/1    1.17371    5.46196    1.14393 +/- 0.01115
#        23/1    1.22481    5.47588    1.14842 +/- 0.01143
#        24/1    1.21640    5.42501    1.15200 +/- 0.01139
#        25/1    1.15830    5.40413    1.15231 +/- 0.01081
#        26/1    1.12345    5.42692    1.15094 +/- 0.01037
#        27/1    1.20006    5.41782    1.15317 +/- 0.01014
#        28/1    1.20463    5.48663    1.15541 +/- 0.00994
#        29/1    1.12602    5.43504    1.15418 +/- 0.00960
#        30/1    1.11863    5.45596    1.15276 +/- 0.00932
#        31/1    1.08283    5.47025    1.15007 +/- 0.00935
#        32/1    1.09395    5.47361    1.14799 +/- 0.00923
#       592/1    1.09686    5.36943    1.15585 +/- 0.00182
#       593/1    1.21348    5.39329    1.15595 +/- 0.00182
#       594/1    1.09631    5.36930    1.15585 +/- 0.00182
#       595/1    1.13725    5.35411    1.15581 +/- 0.00181
#       596/1    1.10161    5.37434    1.15572 +/- 0.00181
#       597/1    1.19444    5.35628    1.15579 +/- 0.00181
#       598/1    1.25602    5.35694    1.15596 +/- 0.00182
#       599/1    1.17485    5.33042    1.15599 +/- 0.00181
#       600/1    1.10596    5.40432    1.15590 +/- 0.00181
#  Creating state point statepoint.600.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.2386e-01 seconds
#    Reading cross sections          = 6.0953e-01 seconds
#  Total time in simulation          = 4.2835e+00 seconds
#    Time in transport only          = 4.2289e+00 seconds
#    Time in inactive batches        = 2.9790e-02 seconds
#    Time in active batches          = 4.2537e+00 seconds
#    Time synchronizing fission bank = 8.1062e-03 seconds
#      Sampling source sites         = 6.5735e-03 seconds
#      SEND/RECV source sites        = 1.2183e-03 seconds
#    Time accumulating tallies       = 3.1506e-02 seconds
#    Time writing statepoints        = 2.1190e-03 seconds
#  Total time for finalization       = 1.0163e-04 seconds
#  Total time elapsed                = 5.0089e+00 seconds
#  Calculation Rate (inactive)       = 167844 particles/second
#  Calculation Rate (active)         = 139878 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.15481 +/- 0.00153
#  k-effective (Track-length)  = 1.15590 +/- 0.00181
#  k-effective (Absorption)    = 1.15296 +/- 0.00139
#  Combined k-effective        = 1.15395 +/- 0.00120
#  Leakage Fraction            = 0.00551 +/- 0.00012

# %%
with openmc.StatePoint(statepoint) as sp:
    entropy = sp.entropy
    
plt.plot(entropy)
plt.xlabel('Batch')
plt.ylabel('Shannon entropy')
# Out:
# Text(0, 0.5, 'Shannon entropy')

# %% [markdown]
# You should choose your number of inactive batches once the Shannon entropy plateaus to a constant value. From this example, we are not using enough particles to see this trend, because our statistical noise is quite high.

# %%
model.settings.particles = 10000
statepoint = model.run(output=False)
with openmc.StatePoint(statepoint) as sp:
    entropy = sp.entropy
    
plt.plot(entropy)
plt.xlabel('Batch')
plt.ylabel('Shannon entropy')
# Out:
# Text(0, 0.5, 'Shannon entropy')

# %% [markdown]
# From the above, it looks like we can justify using about 200 inactive batches. It is common to use a moving window average in order to make this determination more quantitatively.
#
# Note that you will not want to run with Shannon entropy enabled all the time, because the simulation will be quite a bit slower.

# %% [markdown]
# ## Active batches
#
# The number of active batches (`settings.batches - settings.inactive`) are the number of tally realizations we use to accumulate tally statistics. The higher this number, the lower the statistical noise in our result (but remember that unless we properly chose the inactive batches, we could be PRECISE but WRONG!).
#
# The standard deviation in a Monte Carlo tally obeys the central limit theorem, assuming that each batch of neutrons is independent and identically distributed from other batches (more on this later). Then,
#
# $$ \sigma\propto\frac{1}{\sqrt{N}}$$
#
# where $N$ is the number of tally realizations. In other words, if we want to decrease the standard deviation in our simulation by a factor of 2, we would need to run 4 times as many particles.

# %%
# re-init the settings in order to remove the Shannon entropy mesh
model.settings = openmc.Settings()

space = openmc.stats.CartesianIndependent(x=x, y=y, z=z)
model.settings.source = openmc.IndependentSource(space=space)

model.settings.inactive = 100
model.settings.batches = 200
model.settings.particles = 500
statepoint = model.run(apply_tally_results=True)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-
#       169/1    1.07620    1.14884 +/- 0.00728
#       170/1    1.09700    1.14810 +/- 0.00722
#       171/1    1.15308    1.14817 +/- 0.00711
#       172/1    1.18116    1.14862 +/- 0.00703
#       173/1    1.21142    1.14948 +/- 0.00698
#       174/1    1.05587    1.14822 +/- 0.00700
#       175/1    1.14538    1.14818 +/- 0.00691
#       176/1    1.10011    1.14755 +/- 0.00685
#       177/1    1.15244    1.14761 +/- 0.00676
#       178/1    1.15889    1.14776 +/- 0.00667
#       179/1    1.19386    1.14834 +/- 0.00661
#       180/1    1.24067    1.14949 +/- 0.00663
#       181/1    1.18319    1.14991 +/- 0.00656
#       182/1    1.10341    1.14934 +/- 0.00651
#       183/1    1.15924    1.14946 +/- 0.00643
#       184/1    1.06487    1.14846 +/- 0.00643
#       185/1    1.26902    1.14987 +/- 0.00651
#       186/1    1.15125    1.14989 +/- 0.00644
#       187/1    1.24468    1.15098 +/- 0.00645
#       188/1    1.19354    1.15146 +/- 0.00640
#       189/1    1.16006    1.15156 +/- 0.00633
#       190/1    1.21358    1.15225 +/- 0.00629
#       191/1    1.24643    1.15328 +/- 0.00631
#       192/1    1.18592    1.15364 +/- 0.00625
#       193/1    1.10551    1.15312 +/- 0.00621
#       194/1    1.25702    1.15423 +/- 0.00624
#       195/1    0.99719    1.15257 +/- 0.00639
#       196/1    1.15222    1.15257 +/- 0.00632
#       197/1    1.32331    1.15433 +/- 0.00650
#       198/1    1.16572    1.15445 +/- 0.00643
#       199/1    1.02467    1.15313 +/- 0.00650
#       200/1    1.26612    1.15426 +/- 0.00654
#  Creating state point statepoint.200.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.7844e-01 seconds
#    Reading cross sections          = 6.6037e-01 seconds
#  Total time in simulation          = 6.3019e-01 seconds
#    Time in transport only          = 6.2227e-01 seconds
#    Time in inactive batches        = 2.7666e-01 seconds
#    Time in active batches          = 3.5353e-01 seconds
#    Time synchronizing fission bank = 1.3844e-03 seconds
#      Sampling source sites         = 1.1525e-03 seconds
#      SEND/RECV source sites        = 1.4321e-04 seconds
#    Time accumulating tallies       = 3.4485e-03 seconds
#    Time writing statepoints        = 1.9163e-03 seconds
#  Total time for finalization       = 9.4000e-05 seconds
#  Total time elapsed                = 1.4101e+00 seconds
#  Calculation Rate (inactive)       = 180730 particles/second
#  Calculation Rate (active)         = 141431 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.15111 +/- 0.00488
#  k-effective (Track-length)  = 1.15426 +/- 0.00654
#  k-effective (Absorption)    = 1.15183 +/- 0.00419
#  Combined k-effective        = 1.15177 +/- 0.00352
#  Leakage Fraction            = 0.00570 +/- 0.00043

# %% [markdown]
# ### Tally triggers
#
# You most likely will not know, the first time you run your model, what the statistical error will be in your tallies of interest (this will depend on how many "scores" occur to each tally). However, OpenMC has the ability to  keep running batches until a certain condition on a tally is met. These conditions can be set using the variance, standard deviation, or relative error.

# %%
tally_values = heat.get_values(value='rel_err').flatten()
print(tally_values.max())
# Out:
# 0.16146360899713894

# %% [markdown]
# Let's now have OpenMC keep adding batches until reaching a maximum relative error of 10% in the heating tally. With triggers, we need to tell OpenMC how frequently to check whether the triggers are satisfied (`batch_interval`) and a maximum number of batches to run.

# %%
trigger = openmc.Trigger('rel_err', 0.10)
heat.triggers = [trigger]
model.tallies = [heat]

# %%
model.settings.trigger_active = True
model.settings.trigger_batch_interval = 5
model.settings.trigger_max_batches = 1000

# %%
statepoint = model.run(apply_tally_results=True)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-
#       261/1    1.30068    1.15871 +/- 0.00509
#       262/1    1.14437    1.15862 +/- 0.00506
#       263/1    1.15322    1.15859 +/- 0.00503
#       264/1    1.25231    1.15916 +/- 0.00503
#       265/1    1.10789    1.15885 +/- 0.00501
#  Triggers unsatisfied, max unc./thresh. is 1.290505150502057 for kappa-fission
#  in tally 1
#       266/1    1.14826    1.15879 +/- 0.00498
#       267/1    1.08548    1.15835 +/- 0.00497
#       268/1    1.05857    1.15775 +/- 0.00498
#       269/1    1.16672    1.15781 +/- 0.00495
#       270/1    1.33650    1.15886 +/- 0.00503
#  Triggers unsatisfied, max unc./thresh. is 1.277164065137624 for kappa-fission
#  in tally 1
#       271/1    1.07421    1.15836 +/- 0.00502
#       272/1    1.11059    1.15809 +/- 0.00500
#       273/1    1.06995    1.15758 +/- 0.00500
#       274/1    1.03131    1.15685 +/- 0.00502
#       275/1    1.19394    1.15706 +/- 0.00500
#  Triggers unsatisfied, max unc./thresh. is 1.2685094909357941 for kappa-fission
#  in tally 1
#       276/1    1.11534    1.15683 +/- 0.00498
#       277/1    1.19443    1.15704 +/- 0.00495
#       278/1    1.17251    1.15713 +/- 0.00493
#       279/1    1.16425    1.15717 +/- 0.00490
#       280/1    1.19046    1.15735 +/- 0.00488
#  Triggers unsatisfied, max unc./thresh. is 1.2542982916098335 for kappa-fission
#  in tally 1
#       281/1    1.21395    1.15766 +/- 0.00486
#       282/1    1.18432    1.15781 +/- 0.00483
#       283/1    1.27671    1.15846 +/- 0.00485
#       284/1    1.21159    1.15875 +/- 0.00483
#       285/1    1.28344    1.15942 +/- 0.00485
#  Triggers unsatisfied, max unc./thresh. is 1.2367515690154118 for kappa-fission
#  in tally 1
#       286/1    0.98794    1.15850 +/- 0.00491
#       287/1    1.22555    1.15886 +/- 0.00490
#       288/1    1.07848    1.15843 +/- 0.00489
#       289/1    1.14831    1.15838 +/- 0.00487
#       290/1    1.13303    1.15824 +/- 0.00484
#  Triggers unsatisfied, max unc./thresh. is 1.2406402635592224 for kappa-fission
#  in tally 1
#       291/1    1.18046    1.15836 +/- 0.00482
#       292/1    1.15090    1.15832 +/- 0.00480
#       293/1    1.11220    1.15808 +/- 0.00478
#       294/1    1.17929    1.15819 +/- 0.00475
#       295/1    1.23463    1.15858 +/- 0.00475
#  Triggers unsatisfied, max unc./thresh. is 1.242694549477755 for kappa-fission
#  in tally 1
#       296/1    1.17382    1.15866 +/- 0.00472
#       297/1    1.17129    1.15873 +/- 0.00470
#       298/1    1.14656    1.15866 +/- 0.00467
#       299/1    1.11327    1.15844 +/- 0.00466
#       300/1    1.26153    1.15895 +/- 0.00466
#  Triggers unsatisfied, max unc./thresh. is 1.2093566100318696 for kappa-fission
#  in tally 1
#       301/1    1.18156    1.15906 +/- 0.00464
#       302/1    1.13109    1.15893 +/- 0.00462
#       303/1    1.17425    1.15900 +/- 0.00460
#       304/1    1.11823    1.15880 +/- 0.00458
#       305/1    1.19052    1.15896 +/- 0.00456
#  Triggers unsatisfied, max unc./thresh. is 1.0684595483994956 for kappa-fission
#  in tally 1
#       351/1    1.13861    1.15800 +/- 0.00411
#       352/1    1.21490    1.15823 +/- 0.00410
#       353/1    1.27606    1.15870 +/- 0.00411
#       354/1    1.15027    1.15866 +/- 0.00410
#       355/1    1.20522    1.15885 +/- 0.00408
#  Triggers unsatisfied, max unc./thresh. is 1.0623915508258257 for kappa-fission
#  in tally 1
#       356/1    1.10145    1.15862 +/- 0.00407
#       357/1    1.26350    1.15903 +/- 0.00408
#       358/1    1.11705    1.15887 +/- 0.00407
#       359/1    1.05388    1.15846 +/- 0.00407
#       360/1    1.23620    1.15876 +/- 0.00407
#  Triggers unsatisfied, max unc./thresh. is 1.0659085118286022 for kappa-fission
#  in tally 1
#       361/1    1.12552    1.15863 +/- 0.00405
#       362/1    1.15952    1.15864 +/- 0.00404
#       363/1    1.18298    1.15873 +/- 0.00402
#       364/1    1.05125    1.15832 +/- 0.00403
#       365/1    1.21399    1.15853 +/- 0.00402
#  Triggers unsatisfied, max unc./thresh. is 1.0537129330805466 for kappa-fission
#  in tally 1
#       366/1    1.18044    1.15861 +/- 0.00400
#       367/1    1.17663    1.15868 +/- 0.00399
#       368/1    1.19538    1.15882 +/- 0.00398
#       369/1    1.10803    1.15863 +/- 0.00397
#       370/1    1.04844    1.15822 +/- 0.00397
#  Triggers unsatisfied, max unc./thresh. is 1.038544103726129 for kappa-fission
#  in tally 1
#       371/1    1.17248    1.15827 +/- 0.00396
#       372/1    1.14769    1.15824 +/- 0.00394
#       373/1    1.19146    1.15836 +/- 0.00393
#       374/1    1.18616    1.15846 +/- 0.00392
#       375/1    1.06742    1.15813 +/- 0.00392
#  Triggers unsatisfied, max unc./thresh. is 1.0331468563111836 for kappa-fission
#  in tally 1
#       376/1    1.10405    1.15793 +/- 0.00391
#       377/1    1.13717    1.15786 +/- 0.00390
#       378/1    1.10665    1.15767 +/- 0.00389
#       379/1    1.20150    1.15783 +/- 0.00388
#       380/1    1.00577    1.15729 +/- 0.00390
#  Triggers unsatisfied, max unc./thresh. is 1.0313310542740397 for kappa-fission
#  in tally 1
#       381/1    1.13518    1.15721 +/- 0.00389
#       382/1    1.19515    1.15734 +/- 0.00387
#       383/1    1.22961    1.15760 +/- 0.00387
#       384/1    1.07301    1.15730 +/- 0.00387
#       385/1    1.14839    1.15727 +/- 0.00385
#  Triggers unsatisfied, max unc./thresh. is 1.0248098334519573 for kappa-fission
#  in tally 1
#       386/1    1.16059    1.15728 +/- 0.00384
#       387/1    1.19891    1.15743 +/- 0.00383
#       388/1    1.21872    1.15764 +/- 0.00382
#       389/1    1.22629    1.15788 +/- 0.00382
#       390/1    1.13485    1.15780 +/- 0.00380
#  Triggers unsatisfied, max unc./thresh. is 1.0193108383898184 for kappa-fission
#  in tally 1
#       391/1    1.09148    1.15757 +/- 0.00380
#       392/1    1.15454    1.15756 +/- 0.00378
#       393/1    1.13201    1.15747 +/- 0.00377
#       394/1    1.25622    1.15781 +/- 0.00378
#       395/1    1.10050    1.15761 +/- 0.00377
#  Triggers unsatisfied, max unc./thresh. is 1.0176648201632423 for kappa-fission
#  in tally 1
#       396/1    1.13692    1.15754 +/- 0.00376
#       397/1    1.15671    1.15754 +/- 0.00374
#       398/1    1.24170    1.15782 +/- 0.00374
#       399/1    1.10066    1.15763 +/- 0.00373
#       400/1    1.15566    1.15762 +/- 0.00372
#  Triggers unsatisfied, max unc./thresh. is 1.0189841160723874 for kappa-fission
#  in tally 1
#       401/1    1.16639    1.15765 +/- 0.00371
#       402/1    1.10900    1.15749 +/- 0.00370
#       403/1    1.05364    1.15715 +/- 0.00370
#       404/1    1.12590    1.15705 +/- 0.00369
#       405/1    1.24371    1.15733 +/- 0.00369
#  Triggers unsatisfied, max unc./thresh. is 1.0054199154060321 for kappa-fission
#  in tally 1
#       406/1    1.13960    1.15727 +/- 0.00368
#       407/1    1.16019    1.15728 +/- 0.00367
#       408/1    1.14112    1.15723 +/- 0.00366
#       409/1    1.18197    1.15731 +/- 0.00365
#       410/1    1.11851    1.15718 +/- 0.00364
#  Triggers satisfied for batch 410
#  Creating state point statepoint.0410.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.1451e-01 seconds
#    Reading cross sections          = 6.0002e-01 seconds
#  Total time in simulation          = 1.3889e+00 seconds
#    Time in transport only          = 1.3696e+00 seconds
#    Time in inactive batches        = 2.8463e-01 seconds
#    Time in active batches          = 1.1043e+00 seconds
#    Time synchronizing fission bank = 2.8331e-03 seconds
#      Sampling source sites         = 2.3705e-03 seconds
#      SEND/RECV source sites        = 2.9259e-04 seconds
#    Time accumulating tallies       = 1.0739e-02 seconds
#    Time writing statepoints        = 3.1572e-03 seconds
#  Total time for finalization       = 1.0242e-04 seconds
#  Total time elapsed                = 2.1049e+00 seconds
#  Calculation Rate (inactive)       = 175665 particles/second
#  Calculation Rate (active)         = 140366 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.15654 +/- 0.00298
#  k-effective (Track-length)  = 1.15718 +/- 0.00364
#  k-effective (Absorption)    = 1.15381 +/- 0.00265
#  Combined k-effective        = 1.15501 +/- 0.00229
#  Leakage Fraction            = 0.00430 +/- 0.00022

# %%
tally_values = heat.get_values(value='rel_err').flatten()
print(tally_values.max())
# Out:
# 0.09958995912440063

# %% [markdown]
# We can also add a trigger to the multiplication factor. When you have multiple triggers, the simulation will only terminate once all are satisfied (or you reach `max_batches`).

# %%
model.settings.keff_trigger = {'type': 'std_dev', 'threshold': 0.00200}

# %%
statepoint = model.run(apply_tally_results=True)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2026 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.4-dev144
#      Commit Hash | 9ff50499e133e1b977391dd1ff284b9eccb08958
#        Date/Time | 2026-06-10 16:36:28
#    MPI Processes | 1
#   OpenMP Threads | 10
#
#  Reading model XML file 'model.xml' ...
#  Reading chain file:
#  /Users/anovak/projects/cross_sections/endfb-vii.1-hdf5/depletion_chain.xml...
#  Reading cross sections XML file...
#  Reading U234 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U234.h5
#  Reading U235 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U235.h5
#  Reading U238 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/U238.h5
#  Reading O16 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/O16.h5
#  Reading Zr90 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr90.h5
#  Reading Zr91 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr91.h5
#  Reading Zr92 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr92.h5
#  Reading Zr94 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr94.h5
#  Reading Zr96 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/Zr96.h5
#  WARNING: Negative value(s) found on probability table for nuclide Zr96 at 294K
#  Reading H1 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/H1.h5
#  Reading B10 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/B10.h5
#  Reading B11 from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/neutron/B11.h5
#  Reading c_H_in_H2O from
#  /Users/anovak/projects/cross_sections/endfb-viii.0-hdf5/thermal/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Zr90
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.
#       324/1    1.11839    1.15850 +/- 0.00443
#       325/1    1.16654    1.15854 +/- 0.00441
#  Triggers unsatisfied, max unc./thresh. is 1.3486764793399495 for eigenvalue
#       326/1    1.20361    1.15874 +/- 0.00439
#       327/1    1.20315    1.15894 +/- 0.00438
#       328/1    1.25517    1.15936 +/- 0.00438
#       329/1    1.22151    1.15963 +/- 0.00437
#       330/1    1.18952    1.15976 +/- 0.00435
#  Triggers unsatisfied, max unc./thresh. is 1.3434165605790853 for eigenvalue
#       331/1    1.10320    1.15951 +/- 0.00434
#       332/1    1.05699    1.15907 +/- 0.00434
#       333/1    1.19358    1.15922 +/- 0.00433
#       334/1    1.21153    1.15944 +/- 0.00431
#       335/1    1.09852    1.15918 +/- 0.00430
#  Triggers unsatisfied, max unc./thresh. is 1.330585169497518 for eigenvalue
#       336/1    1.16417    1.15921 +/- 0.00429
#       337/1    1.18472    1.15931 +/- 0.00427
#       338/1    1.09640    1.15905 +/- 0.00426
#       339/1    1.10914    1.15884 +/- 0.00425
#       340/1    1.08898    1.15855 +/- 0.00424
#  Triggers unsatisfied, max unc./thresh. is 1.3065967150914688 for eigenvalue
#       341/1    1.04859    1.15809 +/- 0.00425
#       342/1    1.15168    1.15807 +/- 0.00423
#       343/1    1.16949    1.15811 +/- 0.00421
#       344/1    1.26433    1.15855 +/- 0.00422
#       345/1    1.12452    1.15841 +/- 0.00420
#  Triggers unsatisfied, max unc./thresh. is 1.2883367216970008 for eigenvalue
#       346/1    1.13722    1.15832 +/- 0.00418
#       347/1    1.18611    1.15844 +/- 0.00417
#       348/1    1.10338    1.15821 +/- 0.00416
#       349/1    1.12146    1.15807 +/- 0.00414
#       350/1    1.16203    1.15808 +/- 0.00413
#  Triggers unsatisfied, max unc./thresh. is 1.290753593359886 for eigenvalue
#       351/1    1.13861    1.15800 +/- 0.00411
#       352/1    1.21490    1.15823 +/- 0.00410
#       353/1    1.27606    1.15870 +/- 0.00411
#       354/1    1.15027    1.15866 +/- 0.00410
#       355/1    1.20522    1.15885 +/- 0.00408
#  Triggers unsatisfied, max unc./thresh. is 1.2730867085064421 for eigenvalue
#       356/1    1.10145    1.15862 +/- 0.00407
#       357/1    1.26350    1.15903 +/- 0.00408
#       358/1    1.11705    1.15887 +/- 0.00407
#       359/1    1.05388    1.15846 +/- 0.00407
#       360/1    1.23620    1.15876 +/- 0.00407
#  Triggers unsatisfied, max unc./thresh. is 1.2745145498140131 for eigenvalue
#       361/1    1.12552    1.15863 +/- 0.00405
#       362/1    1.15952    1.15864 +/- 0.00404
#       363/1    1.18298    1.15873 +/- 0.00402
#       364/1    1.05125    1.15832 +/- 0.00403
#       365/1    1.21399    1.15853 +/- 0.00402
#  Triggers unsatisfied, max unc./thresh. is 1.2673872591568387 for eigenvalue
#       366/1    1.18044    1.15861 +/- 0.00400
#       367/1    1.17663    1.15868 +/- 0.00399
#       368/1    1.19538    1.15882 +/- 0.00398
#       369/1    1.10803    1.15863 +/- 0.00397
#       462/1    1.09478    1.15729 +/- 0.00332
#       463/1    1.02623    1.15692 +/- 0.00333
#       464/1    1.15859    1.15693 +/- 0.00332
#       465/1    1.05003    1.15664 +/- 0.00332
#  Triggers unsatisfied, max unc./thresh. is 1.0259337272301416 for eigenvalue
#       466/1    1.10974    1.15651 +/- 0.00331
#       467/1    1.19606    1.15662 +/- 0.00331
#       468/1    1.21101    1.15676 +/- 0.00330
#       469/1    1.14309    1.15673 +/- 0.00329
#       470/1    1.12333    1.15664 +/- 0.00328
#  Triggers unsatisfied, max unc./thresh. is 1.0277673049309117 for eigenvalue
#       471/1    1.25696    1.15691 +/- 0.00329
#       472/1    1.16583    1.15693 +/- 0.00328
#       473/1    1.09897    1.15677 +/- 0.00327
#       474/1    1.16843    1.15681 +/- 0.00326
#       475/1    1.21721    1.15697 +/- 0.00326
#  Triggers unsatisfied, max unc./thresh. is 1.0213577731065568 for eigenvalue
#       476/1    1.13993    1.15692 +/- 0.00325
#       477/1    1.05748    1.15666 +/- 0.00325
#       478/1    1.22770    1.15685 +/- 0.00325
#       479/1    1.17955    1.15691 +/- 0.00324
#       480/1    1.15639    1.15690 +/- 0.00323
#  Triggers unsatisfied, max unc./thresh. is 1.0155761791421194 for eigenvalue
#       481/1    1.24654    1.15714 +/- 0.00323
#       482/1    1.19551    1.15724 +/- 0.00323
#       483/1    1.15752    1.15724 +/- 0.00322
#       484/1    1.22813    1.15743 +/- 0.00322
#       485/1    1.16958    1.15746 +/- 0.00321
#  Triggers unsatisfied, max unc./thresh. is 1.0057221738381474 for eigenvalue
#       486/1    1.11388    1.15734 +/- 0.00320
#       487/1    1.19956    1.15745 +/- 0.00319
#       488/1    1.09698    1.15730 +/- 0.00319
#       489/1    1.24394    1.15752 +/- 0.00319
#       490/1    1.11107    1.15740 +/- 0.00318
#  Triggers satisfied for batch 490
#  Creating state point statepoint.0490.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.2823e-01 seconds
#    Reading cross sections          = 6.1344e-01 seconds
#  Total time in simulation          = 1.6553e+00 seconds
#    Time in transport only          = 1.6322e+00 seconds
#    Time in inactive batches        = 2.7674e-01 seconds
#    Time in active batches          = 1.3785e+00 seconds
#    Time synchronizing fission bank = 3.3601e-03 seconds
#      Sampling source sites         = 2.8022e-03 seconds
#      SEND/RECV source sites        = 3.4783e-04 seconds
#    Time accumulating tallies       = 1.3476e-02 seconds
#    Time writing statepoints        = 3.1906e-03 seconds
#  Total time for finalization       = 9.9041e-05 seconds
#  Total time elapsed                = 2.3850e+00 seconds
#  Calculation Rate (inactive)       = 180674 particles/second
#  Calculation Rate (active)         = 141457 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.15694 +/- 0.00259
#  k-effective (Track-length)  = 1.15740 +/- 0.00318
#  k-effective (Absorption)    = 1.15527 +/- 0.00234
#  Combined k-effective        = 1.15604 +/- 0.00199
#  Leakage Fraction            = 0.00451 +/- 0.00019

# %% [markdown]
# ## Inter-Cycle Correlation
#
# For the central limit theorm to apply, each batch of particles which is used to assembly a tally realization should be INDEPENDENT. However, this is obviously not the case, since we sample the birth sites for neutrons in batch $i$ from the the fission sites from batch $i-1$. This is called "inter-cycle correlation," and means that the actual variances reported by a Monte Carlo code *underpredict* the true variance.
#
# One way that you can increase the independence of batches is to set `settings.generations_per_batch` to a number greater than 1. This will effectively increase the independence of each batch by reduce the cross-correlation between the fission bank of other batches.
#
# You can quantify the extent of inter-cycle correlation by running OpenMC repeated times using different seeds. The mean and standard deviation of those estimates have the inter-cycle correlation removed. In order for these runs to be faster, we can drastically reduce the number of inactive batches (of course, our answers are wrong, but right now we are only exploring the inter-cycle correlation aspect, which is independent of the inactive batch choice).
#
# In our example, we will use triggers on the multiplication factor so that each of our simulations run to a tolerance of 120 pcm - but we will see that the *actual* variance is higher due to inter-cycle correlation.

# %%
model.tallies = []

model.settings.inactive = 10
model.settings.batches = 50
model.settings.particles = 1000

# %%
n = 1
import random

model.settings.keff_trigger = {'type': 'std_dev', 'threshold': 0.00120}
model.settings.trigger_active = True
model.settings.trigger_batch_interval = 2
model.settings.trigger_max_batches = 1000

k_values = []
k_std_dev_values = []
while n <= 50:
    model.settings.seed = random.randint(0, 100000)
    statepoint = model.run(output=False)
    
    with openmc.StatePoint(statepoint) as sp:
        k_values.append(sp.keff.nominal_value)
        k_std_dev_values.append(sp.keff.std_dev)
        
    print('Ran OpenMC with seed = {0} ... k = {1} +/- {2}'.format(n, k_values[-1], k_std_dev_values[-1]))
    
    n += 1
# Out:
# Ran OpenMC with seed = 1 ... k = 1.1527591050443948 +/- 0.0011923770557064875
# Ran OpenMC with seed = 2 ... k = 1.154397001398607 +/- 0.001192348361596566
# Ran OpenMC with seed = 3 ... k = 1.153428626849848 +/- 0.001190134871557376
# Ran OpenMC with seed = 4 ... k = 1.152560329333469 +/- 0.0011944935709355265
# Ran OpenMC with seed = 5 ... k = 1.1544305763423914 +/- 0.001187716777588973
# Ran OpenMC with seed = 6 ... k = 1.1545323873592777 +/- 0.0011856816612622054
# Ran OpenMC with seed = 7 ... k = 1.1526985731923336 +/- 0.0011956463452809667
# Ran OpenMC with seed = 8 ... k = 1.152457675426401 +/- 0.001199000698583062
# Ran OpenMC with seed = 9 ... k = 1.1534915385622546 +/- 0.0011892130585410086
# Ran OpenMC with seed = 10 ... k = 1.151034500568475 +/- 0.0011966184632544287
# Ran OpenMC with seed = 11 ... k = 1.1559249046345201 +/- 0.0011995068295699495
# Ran OpenMC with seed = 12 ... k = 1.153581197903485 +/- 0.0011918141688541523
# Ran OpenMC with seed = 13 ... k = 1.152387894970404 +/- 0.0011833865818687325
# Ran OpenMC with seed = 14 ... k = 1.1514195236949492 +/- 0.0011998745976227938
# Ran OpenMC with seed = 15 ... k = 1.1526474791509416 +/- 0.0011901434611798932
# Ran OpenMC with seed = 16 ... k = 1.1533298136292922 +/- 0.0011995182097768833
# Ran OpenMC with seed = 17 ... k = 1.1515608803734205 +/- 0.0011963032616481332
# Ran OpenMC with seed = 18 ... k = 1.1507675365926544 +/- 0.0011954492025144418
# Ran OpenMC with seed = 19 ... k = 1.1524797966855833 +/- 0.0011931295403237961
# Ran OpenMC with seed = 20 ... k = 1.152987191654818 +/- 0.0011966722110253202
# Ran OpenMC with seed = 21 ... k = 1.1529478827512156 +/- 0.0011926555270819511
# Ran OpenMC with seed = 22 ... k = 1.151560522659488 +/- 0.0011896629008856844
# Ran OpenMC with seed = 23 ... k = 1.1501397628578298 +/- 0.0011922529788904249
# Ran OpenMC with seed = 24 ... k = 1.1535496073551201 +/- 0.0011989081759587808
# Ran OpenMC with seed = 25 ... k = 1.1535894950896854 +/- 0.0011985291936748572
# Ran OpenMC with seed = 26 ... k = 1.1515765515050327 +/- 0.001186396400802477
# Ran OpenMC with seed = 27 ... k = 1.154920410463321 +/- 0.0011949668194408732
# Ran OpenMC with seed = 28 ... k = 1.150732807943394 +/- 0.0011996671118457741
# Ran OpenMC with seed = 29 ... k = 1.1541965205528357 +/- 0.0011951452881745327
# Ran OpenMC with seed = 30 ... k = 1.1523541857113073 +/- 0.0011975490411336013
# Ran OpenMC with seed = 31 ... k = 1.1530842746861418 +/- 0.0011930934929686068
# Ran OpenMC with seed = 32 ... k = 1.151852479580743 +/- 0.0011941329668153473
# Ran OpenMC with seed = 33 ... k = 1.1538192367311737 +/- 0.001186913543389963
# Ran OpenMC with seed = 34 ... k = 1.154037756137241 +/- 0.001192345168229862
# Ran OpenMC with seed = 35 ... k = 1.1512734579906554 +/- 0.0011933059017174919
# Ran OpenMC with seed = 36 ... k = 1.1516039390661421 +/- 0.0011914433479349581
# Ran OpenMC with seed = 37 ... k = 1.152915482500528 +/- 0.0011946724198687532
# Ran OpenMC with seed = 38 ... k = 1.1526215658543135 +/- 0.001191497213733249
# Ran OpenMC with seed = 39 ... k = 1.1540596684657172 +/- 0.0011970317856673505
# Ran OpenMC with seed = 40 ... k = 1.1524891359681622 +/- 0.0011925230971600814
# Ran OpenMC with seed = 41 ... k = 1.1523863744350582 +/- 0.001193961988928591
# Ran OpenMC with seed = 42 ... k = 1.1527188748242017 +/- 0.0011989077564761768
# Ran OpenMC with seed = 43 ... k = 1.1506601667041203 +/- 0.0011960516550917372
# Ran OpenMC with seed = 44 ... k = 1.1518327707181681 +/- 0.0011888851199237912
# Ran OpenMC with seed = 45 ... k = 1.1533919169317233 +/- 0.0011929987159642005
# Ran OpenMC with seed = 46 ... k = 1.1538178636694632 +/- 0.0011917345084697293
# Ran OpenMC with seed = 47 ... k = 1.1526620619581405 +/- 0.0011881932029122577
# Ran OpenMC with seed = 48 ... k = 1.1507634933156452 +/- 0.001192472347586994
# Ran OpenMC with seed = 49 ... k = 1.1520983266123492 +/- 0.0011992407557923758
# Ran OpenMC with seed = 50 ... k = 1.1522437819717124 +/- 0.0011952545975206419

# %%
import numpy as np
mean = np.mean(k_values)
std_dev = np.std(k_values)

print(mean, std_dev)
# Out:
# 1.152695538167563 0.0012142611778775798

# %% [markdown]
# Notice how the standard deviation we compute of the multiple independent runs is HIGHER than the values reported from any individual OpenMC solve. This occurs because each batch is not truly independent of the other batches.

# %%
model.settings.generations_per_batch = 10
